# %% [markdown]
# ## Week 3 homework example
# This is just an example of how to use the [2024 Living Atlas Dataset](https://github.com/cgiamarino9/PubAff405_S25/blob/main/Weeks/Week03%20Census%20Data/data/LACountyTracts24.zip) from our course website referencing the [data dictionary from Esri](https://www.arcgis.com/home/item.html?id=b0b3b31e531e406185f2de4fff596060).
#
# **Do not copy this exactly. Use different quantitative columns. Keep ID and geometry columns.**. Be sure to keep `ID` and `geometry` so the tracts can be mapped with Geopandas.

# %%
import geopandas as gpd

# %%
tracts=gpd.read_file('Data/LACountyTracts24.zip')

# %%
tracts.head()
# Out:
#             ID          NAME  STATE_NAME ST_ABBREV      AREA  TOTPOP_CY  \
# 0  06037262302  060372623.02  California        CA  1.182838       2782
# 1  06037206201  060372062.01  California        CA  0.077543       2863
# 2  06037128102  060371281.02  California        CA  0.250507       4755
# 3  06037131701  060371317.01  California        CA  0.254699       4591
# 4  06037232800  060372328.00  California        CA  0.164729       3927
#
#    HHPOP_CY  GQPOP_CY  POPDENS_CY  TOTHH_CY  ...  NHSPWHT__1  NHSPBLK__1  \
# 0      2765        17      2352.0      1141  ...   79.295471    1.042416
# 1      2202       661     36941.9      1262  ...   20.852253   16.590988
# 2      4521       234     18982.0      1479  ...   18.401682    5.005258
# 3      4575        16     18025.1      1741  ...   23.175779    5.968199
# 4      3858        69     23843.4       968  ...    0.993125   12.554113
#
#    NHSPAI_CY_  NHSPASN__1  NHSPPI_CY_  NHSPOTH__1  NHSPMLT__1  HSGRAD_LES  \
# 0    0.000000    6.506111    0.000000    1.006470    5.140187    0.824043
# 1    1.012924   28.815927    0.419141    0.838282    4.680405    9.677419
# 2    0.042061    5.615142    0.147213    0.672976    1.451104   25.774135
# 3    0.174254   21.367894    0.043563    0.588107    3.724679   17.841079
# 4    0.254647    0.611154    0.000000    0.891266    1.120448   43.775763
#
#    BACHDEG_PL                                           geometry
# 0   83.131362  POLYGON ((-13187629.788 4038588.873, -13187642...
# 1   45.822994  POLYGON ((-13162511.881 4035572.196, -13162582...
# 2   17.941712  POLYGON ((-13184678.486 4053894.2, -13184921.4...
# 3   34.002999  POLYGON ((-13197317.144 4055820.492, -13197556...
# 4   10.634790  POLYGON ((-13166681.241 4028231.101, -13166681...
#
# [5 rows x 206 columns]

# %%
# define columns to keep; you will have to look at your source's metadata to determine which columns to keep and what they mean
columns_to_keep = ['ID',
                   'TOTPOP_CY',
                   'POPDENS_CY',
                   'DIVINDX_CY',
                   'geometry']

# add it to a new dataframe
tractsCleaned = tracts[columns_to_keep]

# %%
tractsCleaned.columns = ['FIPS',
               'Total Population (2024)',
               'Population Density (2024',
               'Diversity Index (2024)',
               'geometry']

# %%
tractsCleaned.head()
# Out:
#           FIPS  Total Population (2024)  Population Density (2024  \
# 0  06037262302                     2782                    2352.0
# 1  06037206201                     2863                   36941.9
# 2  06037128102                     4755                   18982.0
# 3  06037131701                     4591                   18025.1
# 4  06037232800                     3927                   23843.4
#
#    Diversity Index (2024)                                           geometry
# 0                    41.7  POLYGON ((-13187629.788 4038588.873, -13187642...
# 1                    87.0  POLYGON ((-13162511.881 4035572.196, -13162582...
# 2                    82.8  POLYGON ((-13184678.486 4053894.2, -13184921.4...
# 3                    88.5  POLYGON ((-13197317.144 4055820.492, -13197556...
# 4                    71.7  POLYGON ((-13166681.241 4028231.101, -13166681...

# %%
tractsCleaned.type
# Out:
# 0            Polygon
# 1            Polygon
# 2            Polygon
# 3            Polygon
# 4            Polygon
#             ...
# 2528    MultiPolygon
# 2529         Polygon
# 2530         Polygon
# 2531         Polygon
# 2532    MultiPolygon
# Length: 2533, dtype: object

# %%
tractsCleaned.plot()
# Out:
# <Axes: >

# %%
tractsCleaned.plot(figsize=(12,10),
                 column='Diversity Index (2024)',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >
